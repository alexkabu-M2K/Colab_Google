# %% [markdown]
# <a href="https://colab.research.google.com/github/alexkabu-M2K/Colab_Google_Estacio/blob/main/Projeto_An%C3%A1lise_Imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from skimage import io
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

origem = "http://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png"
img_original = io.imread(origem)
img_cinza = cv2.cvtColor(img_original, cv2.COLOR_RGB2GRAY)

fig, ax = plt.subplots(1, 2,
figsize=(10, 6))
fig.tight_layout()
ax[0].imshow(cv2.cvtColor(img_original,
cv2.COLOR_BGR2RGB))
ax[0].set_title("Original")
ax[1].imshow(cv2.cvtColor(img_cinza,
cv2.COLOR_BGR2RGB))
ax[1].set_title("Tons de Cinza")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-2131298643.py in <cell line: 0>()
#       6
#       7 origem = "http://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png"
# ----> 8 img_original = io.imread(origem)
#       9 img_cinza = cv2.cvtColor(img_original, cv2.COLOR_RGB2GRAY)
#      10
#
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     326                     kwargs[self.new_name] = deprecated_value
#     327
# --> 328             return func(*args, **kwargs)
#     329
#     330         if self.modify_docstring and func.__doc__ is not None:
#
# /usr/local/lib/python3.12/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      79             plugin = 'tifffile'
#      80
# ...
